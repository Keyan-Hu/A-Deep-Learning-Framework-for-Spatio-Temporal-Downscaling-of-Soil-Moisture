# %%
import sys
import torch
import argparse
sys.path.append(r"C:\Users\Administrator\Desktop\code\ST-Conv")
from torchstat import stat
from model.block import BasicBlock,Bottleneck
from model.model import STConvNet
from tool.utils import Util
from torchsummaryX import summary
from fvcore.nn import FlopCountAnalysis, parameter_count_table

def flops_to_string(flops, units='GFLOPs', precision=2):
    """Convert FLOPs to a human readable string."""
    if units == 'GFLOPs':
        flops_count = flops / 1e9
    elif units == 'MFLOPs':
        flops_count = flops / 1e6
    else:  # Default to FLOPs
        flops_count = flops
    return f"{flops_count:.{precision}f} {units}"

def main(args):
    model_config = Util.load_config(args.model_config_path)
    path_config = Util.load_config(args.path_config_path)
    return model_config, path_config

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--path_config_path', type=str, default='../config/path_config.yaml')
    parser.add_argument('--model_config_path', type=str, default='../config/model_config.yaml')
    args = parser.parse_known_args()[0]
    Hyperparameter_dict, path_dict = main(args)
    
    # 设定设备
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 从Hyperparameter_dict获取batch_size，或者设置一个特定的值
    batch_size = Hyperparameter_dict['batch_size']

    # 创建模拟输入
    hour_input_shape = (batch_size, Hyperparameter_dict['hour_in_channels'], 17, 16, 16)
    day_input_shape = (batch_size, Hyperparameter_dict['day_in_channels'], 5, 16, 16)
    half_day_input_shape = (batch_size, 1, 9, 16, 16)
    static_input_shape = (batch_size, 11, 16, 16)

    # 创建模拟数据
    hour_input = torch.randn(hour_input_shape)
    day_input = torch.randn(day_input_shape)
    half_day_input = torch.randn(half_day_input_shape)
    static_input = torch.randn(static_input_shape)
    print("Hour input shape:", hour_input_shape)
    print("Day input shape:", day_input_shape)
    print("Half day input shape:", half_day_input_shape)
    print("Static input shape:", static_input_shape)
    # 创建模型
    model = STConvNet(Hyperparameter_dict['hour_in_channels'],Hyperparameter_dict['hour_step'], 
                      Hyperparameter_dict['day_in_channels'],Hyperparameter_dict['day_step'], 
                      Hyperparameter_dict['half_day_in_channels'],Hyperparameter_dict['half_day_step'], 
                      Hyperparameter_dict['static_in_channels'],Hyperparameter_dict['temporal_kernel_size'], Hyperparameter_dict['target_time_steps'],
                    BasicBlock, Hyperparameter_dict['layer18'], Hyperparameter_dict['spatial_out_channels'])

    # 模型分析
    model.cpu()
    summary(model, hour_input, day_input, half_day_input, static_input)
    # FLOPs 和 参数 统计
    flop_analyzer = FlopCountAnalysis(model, (hour_input, day_input, half_day_input, static_input))


    # 在模型分析的代码中使用这个函数
    flops = flop_analyzer.total()
    print(f"FLOPs: {flops_to_string(flops, 'MFLOPs')}")
    print(parameter_count_table(model))
# Out:
# Hour input shape: (32, 8, 17, 16, 16)
# Day input shape: (32, 22, 5, 16, 16)
# Half day input shape: (32, 1, 9, 16, 16)
# Static input shape: (32, 11, 16, 16)
# c:\Anaconda\envs\MLL\lib\site-packages\torchsummaryX\torchsummaryX.py:101: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_sum = df.sum()
# ========================================================================================================================
#                                                           Kernel Shape          Output Shape     Params   Mult-Adds
# Layer
# 0_temporal_conv.hour_block.0.Conv3d_conv              [8, 16, 2, 1, 1]  [32, 16, 16, 16, 16]      272.0   1.048576M
# 1_temporal_conv.hour_block.0.BatchNorm3d_batchnorm                [16]  [32, 16, 16, 16, 16]       32.0        16.0
# 2_temporal_conv.hour_block.0.LeakyReLU_relu                          -  [32, 16, 16, 16, 16]          -           -
# 3_temporal_conv.hour_block.1.Conv3d_conv             [16, 16, 2, 1, 1]  [32, 16, 14, 16, 16]      528.0   1.835008M
# 4_temporal_conv.hour_block.1.BatchNorm3d_batchnorm                [16]  [32, 16, 14, 16, 16]       32.0        16.0
# 5_temporal_conv.hour_block.1.LeakyReLU_relu                          -  [32, 16, 14, 16, 16]          -           -
# 6_temporal_conv.hour_block.2.Conv3d_conv             [16, 16, 2, 1, 1]  [32, 16, 10, 16, 16]      528.0    1.31072M
# 7_temporal_conv.hour_block.2.BatchNorm3d_batchnorm                [16]  [32, 16, 10, 16, 16]       32.0        16.0
# 8_temporal_conv.hour_block.2.LeakyReLU_relu                          -  [32, 16, 10, 16, 16]          -           -
# 9_temporal_conv.hour_block.3.Conv3d_conv             [16, 16, 2, 1, 1]   [32, 16, 2, 16, 16]      528.0    262.144k
# 10_temporal_conv.hour_block.3.BatchNorm3d_batch...                [16]   [32, 16, 2, 16, 16]       32.0        16.0
# 11_temporal_conv.hour_block.3.LeakyReLU_relu                         -   [32, 16, 2, 16, 16]          -           -
# 12_temporal_conv.day_block.0.Conv3d_conv             [22, 44, 2, 1, 1]   [32, 44, 4, 16, 16]      1.98k   1.982464M
# 13_temporal_conv.day_block.0.BatchNorm3d_batchnorm                [44]   [32, 44, 4, 16, 16]       88.0        44.0
# 14_temporal_conv.day_block.0.LeakyReLU_relu                          -   [32, 44, 4, 16, 16]          -           -
# 15_temporal_conv.day_block.1.Conv3d_conv             [44, 44, 2, 1, 1]   [32, 44, 2, 16, 16]     3.916k   1.982464M
# 16_temporal_conv.day_block.1.BatchNorm3d_batchnorm                [44]   [32, 44, 2, 16, 16]       88.0        44.0
# 17_temporal_conv.day_block.1.LeakyReLU_relu                          -   [32, 44, 2, 16, 16]          -           -
# 18_temporal_conv.half_day_block.0.Conv3d_conv          [1, 2, 2, 1, 1]    [32, 2, 8, 16, 16]        6.0      8.192k
# 19_temporal_conv.half_day_block.0.BatchNorm3d_b...                 [2]    [32, 2, 8, 16, 16]        4.0         2.0
# 20_temporal_conv.half_day_block.0.LeakyReLU_relu                     -    [32, 2, 8, 16, 16]          -           -
# 21_temporal_conv.half_day_block.1.Conv3d_conv          [2, 2, 2, 1, 1]    [32, 2, 6, 16, 16]       10.0     12.288k
# 22_temporal_conv.half_day_block.1.BatchNorm3d_b...                 [2]    [32, 2, 6, 16, 16]        4.0         2.0
# 23_temporal_conv.half_day_block.1.LeakyReLU_relu                     -    [32, 2, 6, 16, 16]          -           -
# 24_temporal_conv.half_day_block.2.Conv3d_conv          [2, 2, 2, 1, 1]    [32, 2, 2, 16, 16]       10.0      4.096k
# 25_temporal_conv.half_day_block.2.BatchNorm3d_b...                 [2]    [32, 2, 2, 16, 16]        4.0         2.0
# 26_temporal_conv.half_day_block.2.LeakyReLU_relu                     -    [32, 2, 2, 16, 16]          -           -
# 27_temporal_conv.static_block.Conv2d_0                  [11, 22, 1, 1]      [32, 22, 16, 16]      264.0     61.952k
# 28_temporal_conv.static_block.ReLU_1                                 -      [32, 22, 16, 16]          -           -
# 29_temporal_conv.Conv3d_final_conv                  [62, 124, 2, 1, 1]  [32, 124, 1, 16, 16]      15.5k   3.936256M
# 30_temporal_output                                      [146, 1, 1, 1]       [32, 1, 16, 16]      147.0     37.376k
# 31_spatial_conv.conv1.Conv2d_0                          [42, 64, 5, 5]      [32, 64, 16, 16]      67.2k    17.2032M
# 32_spatial_conv.conv1.BatchNorm2d_1                               [64]      [32, 64, 16, 16]      128.0        64.0
# 33_spatial_conv.conv1.ReLU_2                                         -      [32, 64, 16, 16]          -           -
# 34_spatial_conv.conv1.MaxPool2d_3                                    -      [32, 64, 16, 16]          -           -
# 35_spatial_conv.enc1.0.first.Conv2d_0                  [64, 128, 3, 3]     [32, 128, 16, 16]    73.728k  18.874368M
# 36_spatial_conv.enc1.0.first.BatchNorm2d_1                       [128]     [32, 128, 16, 16]      256.0       128.0
# 37_spatial_conv.enc1.0.first.ReLU_2                                  -     [32, 128, 16, 16]          -           -
# 38_spatial_conv.enc1.0.first.Conv2d_3                 [128, 128, 3, 3]     [32, 128, 16, 16]   147.456k  37.748736M
# 39_spatial_conv.enc1.0.first.BatchNorm2d_4                       [128]     [32, 128, 16, 16]      256.0       128.0
# 40_spatial_conv.enc1.0.down_sample.Conv2d_0            [64, 128, 1, 1]     [32, 128, 16, 16]     8.192k   2.097152M
# 41_spatial_conv.enc1.0.down_sample.BatchNorm2d_1                 [128]     [32, 128, 16, 16]      256.0       128.0
# 42_spatial_conv.enc1.1.first.Conv2d_0                 [128, 128, 3, 3]     [32, 128, 16, 16]   147.456k  37.748736M
# 43_spatial_conv.enc1.1.first.BatchNorm2d_1                       [128]     [32, 128, 16, 16]      256.0       128.0
# 44_spatial_conv.enc1.1.first.ReLU_2                                  -     [32, 128, 16, 16]          -           -
# 45_spatial_conv.enc1.1.first.Conv2d_3                 [128, 128, 3, 3]     [32, 128, 16, 16]   147.456k  37.748736M
# 46_spatial_conv.enc1.1.first.BatchNorm2d_4                       [128]     [32, 128, 16, 16]      256.0       128.0
# 47_spatial_conv.enc2.0.first.Conv2d_0                 [128, 256, 3, 3]       [32, 256, 8, 8]   294.912k  18.874368M
# 48_spatial_conv.enc2.0.first.BatchNorm2d_1                       [256]       [32, 256, 8, 8]      512.0       256.0
# 49_spatial_conv.enc2.0.first.ReLU_2                                  -       [32, 256, 8, 8]          -           -
# 50_spatial_conv.enc2.0.first.Conv2d_3                 [256, 256, 3, 3]       [32, 256, 8, 8]   589.824k  37.748736M
# 51_spatial_conv.enc2.0.first.BatchNorm2d_4                       [256]       [32, 256, 8, 8]      512.0       256.0
# 52_spatial_conv.enc2.0.down_sample.Conv2d_0           [128, 256, 1, 1]       [32, 256, 8, 8]    32.768k   2.097152M
# 53_spatial_conv.enc2.0.down_sample.BatchNorm2d_1                 [256]       [32, 256, 8, 8]      512.0       256.0
# 54_spatial_conv.enc2.1.first.Conv2d_0                 [256, 256, 3, 3]       [32, 256, 8, 8]   589.824k  37.748736M
# 55_spatial_conv.enc2.1.first.BatchNorm2d_1                       [256]       [32, 256, 8, 8]      512.0       256.0
# 56_spatial_conv.enc2.1.first.ReLU_2                                  -       [32, 256, 8, 8]          -           -
# 57_spatial_conv.enc2.1.first.Conv2d_3                 [256, 256, 3, 3]       [32, 256, 8, 8]   589.824k  37.748736M
# 58_spatial_conv.enc2.1.first.BatchNorm2d_4                       [256]       [32, 256, 8, 8]      512.0       256.0
# 59_spatial_conv.enc3.0.first.Conv2d_0                 [256, 512, 3, 3]       [32, 512, 4, 4]  1.179648M  18.874368M
# 60_spatial_conv.enc3.0.first.BatchNorm2d_1                       [512]       [32, 512, 4, 4]     1.024k       512.0
# 61_spatial_conv.enc3.0.first.ReLU_2                                  -       [32, 512, 4, 4]          -           -
# 62_spatial_conv.enc3.0.first.Conv2d_3                 [512, 512, 3, 3]       [32, 512, 4, 4]  2.359296M  37.748736M
# 63_spatial_conv.enc3.0.first.BatchNorm2d_4                       [512]       [32, 512, 4, 4]     1.024k       512.0
# 64_spatial_conv.enc3.0.down_sample.Conv2d_0           [256, 512, 1, 1]       [32, 512, 4, 4]   131.072k   2.097152M
# 65_spatial_conv.enc3.0.down_sample.BatchNorm2d_1                 [512]       [32, 512, 4, 4]     1.024k       512.0
# 66_spatial_conv.enc3.1.first.Conv2d_0                 [512, 512, 3, 3]       [32, 512, 4, 4]  2.359296M  37.748736M
# 67_spatial_conv.enc3.1.first.BatchNorm2d_1                       [512]       [32, 512, 4, 4]     1.024k       512.0
# 68_spatial_conv.enc3.1.first.ReLU_2                                  -       [32, 512, 4, 4]          -           -
# 69_spatial_conv.enc3.1.first.Conv2d_3                 [512, 512, 3, 3]       [32, 512, 4, 4]  2.359296M  37.748736M
# 70_spatial_conv.enc3.1.first.BatchNorm2d_4                       [512]       [32, 512, 4, 4]     1.024k       512.0
# 71_spatial_conv.enc4.0.first.Conv2d_0                [512, 1024, 3, 3]      [32, 1024, 2, 2]  4.718592M  18.874368M
# 72_spatial_conv.enc4.0.first.BatchNorm2d_1                      [1024]      [32, 1024, 2, 2]     2.048k      1.024k
# 73_spatial_conv.enc4.0.first.ReLU_2                                  -      [32, 1024, 2, 2]          -           -
# 74_spatial_conv.enc4.0.first.Conv2d_3               [1024, 1024, 3, 3]      [32, 1024, 2, 2]  9.437184M  37.748736M
# 75_spatial_conv.enc4.0.first.BatchNorm2d_4                      [1024]      [32, 1024, 2, 2]     2.048k      1.024k
# 76_spatial_conv.enc4.0.down_sample.Conv2d_0          [512, 1024, 1, 1]      [32, 1024, 2, 2]   524.288k   2.097152M
# 77_spatial_conv.enc4.0.down_sample.BatchNorm2d_1                [1024]      [32, 1024, 2, 2]     2.048k      1.024k
# 78_spatial_conv.enc4.1.first.Conv2d_0               [1024, 1024, 3, 3]      [32, 1024, 2, 2]  9.437184M  37.748736M
# 79_spatial_conv.enc4.1.first.BatchNorm2d_1                      [1024]      [32, 1024, 2, 2]     2.048k      1.024k
# 80_spatial_conv.enc4.1.first.ReLU_2                                  -      [32, 1024, 2, 2]          -           -
# 81_spatial_conv.enc4.1.first.Conv2d_3               [1024, 1024, 3, 3]      [32, 1024, 2, 2]  9.437184M  37.748736M
# 82_spatial_conv.enc4.1.first.BatchNorm2d_4                      [1024]      [32, 1024, 2, 2]     2.048k      1.024k
# 83_spatial_conv.dec3.ConvTranspose2d_upconv          [512, 1024, 2, 2]       [32, 512, 4, 4]  2.097664M  33.554432M
# 84_spatial_conv.dec3.conv.conv.Conv2d_0              [1024, 512, 3, 3]       [32, 512, 4, 4]  4.719104M  75.497472M
# 85_spatial_conv.dec3.conv.conv.BatchNorm2d_1                     [512]       [32, 512, 4, 4]     1.024k       512.0
# 86_spatial_conv.dec3.conv.conv.ReLU_2                                -       [32, 512, 4, 4]          -           -
# 87_spatial_conv.dec3.conv.conv.Conv2d_3               [512, 512, 3, 3]       [32, 512, 4, 4]  2.359808M  37.748736M
# 88_spatial_conv.dec3.conv.conv.BatchNorm2d_4                     [512]       [32, 512, 4, 4]     1.024k       512.0
# 89_spatial_conv.dec3.conv.conv.ReLU_5                                -       [32, 512, 4, 4]          -           -
# 90_spatial_conv.dec2.ConvTranspose2d_upconv           [256, 512, 2, 2]       [32, 256, 8, 8]   524.544k  33.554432M
# 91_spatial_conv.dec2.conv.conv.Conv2d_0               [512, 256, 3, 3]       [32, 256, 8, 8]  1.179904M  75.497472M
# 92_spatial_conv.dec2.conv.conv.BatchNorm2d_1                     [256]       [32, 256, 8, 8]      512.0       256.0
# 93_spatial_conv.dec2.conv.conv.ReLU_2                                -       [32, 256, 8, 8]          -           -
# 94_spatial_conv.dec2.conv.conv.Conv2d_3               [256, 256, 3, 3]       [32, 256, 8, 8]    590.08k  37.748736M
# 95_spatial_conv.dec2.conv.conv.BatchNorm2d_4                     [256]       [32, 256, 8, 8]      512.0       256.0
# 96_spatial_conv.dec2.conv.conv.ReLU_5                                -       [32, 256, 8, 8]          -           -
# 97_spatial_conv.dec1.ConvTranspose2d_upconv           [128, 256, 2, 2]     [32, 128, 16, 16]     131.2k  33.554432M
# 98_spatial_conv.dec1.conv.conv.Conv2d_0               [256, 128, 3, 3]     [32, 128, 16, 16]    295.04k  75.497472M
# 99_spatial_conv.dec1.conv.conv.BatchNorm2d_1                     [128]     [32, 128, 16, 16]      256.0       128.0
# 100_spatial_conv.dec1.conv.conv.ReLU_2                               -     [32, 128, 16, 16]          -           -
# 101_spatial_conv.dec1.conv.conv.Conv2d_3              [128, 128, 3, 3]     [32, 128, 16, 16]   147.584k  37.748736M
# 102_spatial_conv.dec1.conv.conv.BatchNorm2d_4                    [128]     [32, 128, 16, 16]      256.0       128.0
# 103_spatial_conv.dec1.conv.conv.ReLU_5                               -     [32, 128, 16, 16]          -           -
# 104_spatial_conv.Conv2d_final                           [128, 1, 1, 1]       [32, 1, 16, 16]      129.0     32.768k
# ------------------------------------------------------------------------------------------------------------------------
#                            Totals
# Total params           56.723654M
# Trainable params       56.723654M
# Non-trainable params          0.0
# Mult-Adds             1.00700195G
# ========================================================================================================================
# Unsupported operator aten::add_ encountered 44 time(s)
# Unsupported operator aten::leaky_relu_ encountered 9 time(s)
# Unsupported operator aten::max_pool2d encountered 1 time(s)
# FLOPs: 29917.54 MFLOPs
# | name                               | #elements or shape    |
# |:-----------------------------------|:----------------------|
# | model                              | 56.7M                 |
# |  temporal_conv                     |  23.9K                |
# |   temporal_conv.hour_block         |   2.0K                |
# |    temporal_conv.hour_block.0      |    0.3K               |
# |    temporal_conv.hour_block.1      |    0.6K               |
# |    temporal_conv.hour_block.2      |    0.6K               |
# |    temporal_conv.hour_block.3      |    0.6K               |
# |   temporal_conv.day_block          |   6.1K                |
# |    temporal_conv.day_block.0       |    2.1K               |
# |    temporal_conv.day_block.1       |    4.0K               |
# |   temporal_conv.half_day_block     |   38                  |
# |    temporal_conv.half_day_block.0  |    10                 |
# |    temporal_conv.half_day_block.1  |    14                 |
# |    temporal_conv.half_day_block.2  |    14                 |
# |   temporal_conv.static_block       |   0.3K                |
# |    temporal_conv.static_block.0    |    0.3K               |
# |   temporal_conv.final_conv         |   15.5K               |
# |    temporal_conv.final_conv.weight |    (124, 62, 2, 1, 1) |
# |    temporal_conv.final_conv.bias   |    (124,)             |
# |  temporal_output                   |  0.1K                 |
# |   temporal_output.weight           |   (1, 146, 1, 1)      |
# |   temporal_output.bias             |   (1,)                |
# |  spatial_conv                      |  56.7M                |
# |   spatial_conv.conv1               |   67.3K               |
# |    spatial_conv.conv1.0            |    67.2K              |
# |    spatial_conv.conv1.1            |    0.1K               |
# |   spatial_conv.enc1                |   0.5M                |
# |    spatial_conv.enc1.0             |    0.2M               |
# |    spatial_conv.enc1.1             |    0.3M               |
# |   spatial_conv.enc2                |   2.1M                |
# |    spatial_conv.enc2.0             |    0.9M               |
# |    spatial_conv.enc2.1             |    1.2M               |
# |   spatial_conv.enc3                |   8.4M                |
# |    spatial_conv.enc3.0             |    3.7M               |
# |    spatial_conv.enc3.1             |    4.7M               |
# |   spatial_conv.enc4                |   33.6M               |
# |    spatial_conv.enc4.0             |    14.7M              |
# |    spatial_conv.enc4.1             |    18.9M              |
# |   spatial_conv.dec3                |   9.2M                |
# |    spatial_conv.dec3.upconv        |    2.1M               |
# |    spatial_conv.dec3.conv          |    7.1M               |
# |   spatial_conv.dec2                |   2.3M                |
# |    spatial_conv.dec2.upconv        |    0.5M               |
# |    spatial_conv.dec2.conv          |    1.8M               |
# |   spatial_conv.dec1                |   0.6M                |
# |    spatial_conv.dec1.upconv        |    0.1M               |
# |    spatial_conv.dec1.conv          |    0.4M               |
# |   spatial_conv.final               |   0.1K                |
# |    spatial_conv.final.weight       |    (1, 128, 1, 1)     |
# |    spatial_conv.final.bias         |    (1,)               |

# %%
import numpy as np
file_data = r"D:\Data_Store\Dataset\ST_Conv\std_mean\mean.npy"
data = np.load(file_data)
print(len(data))
